# %% [markdown]
# # POSTTEST 4 KB
# Nama : Rafly Genta Pratama
#
# NIM : 2209106022
#
# Kelas : Informatika A22 (A1)

# %% [markdown]
# ### Mengimport library dan juga mendeklarasikan file csv
# `codingan:`

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder

# %%
df = pd.read_csv('FIFA 19 data.csv')
df
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0               L. Messi   31            Argentina       94         94
# 1      Cristiano Ronaldo   33             Portugal       94         94
# 2              Neymar Jr   26               Brazil       92         93
# 3                 De Gea   27                Spain       91         93
# 4           K. De Bruyne   27              Belgium       91         92
# ...                  ...  ...                  ...      ...        ...
# 17214         S. Griffin   18  Republic of Ireland       47         67
# 17215        K. Fujikawa   19                Japan       47         61
# 17216           J. Young   18             Scotland       47         62
# 17217       J. Lundstram   19              England       47         65
# 17218          B. Worman   16              England       47         67
#
#                       Club        Value      Wage  Special  \
# ...

# %% [markdown]
# ### Bagi dataset menjadi training set dan testing set dengan proporsi 70:30
# `codingan:`

# %%
X = df.drop('Overall', axis=1) # variabel independen 
y = df['Overall'] # variabel dependen 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) # membagi data secara acak

# %% [markdown]
# ### Normalisasi data pada salah satu attribute menggunakan Min Max scaler
# `codingan:`

# %%
df_norm = df.copy() # membuat salinan dataset 
scaler = MinMaxScaler() # membuat objek scaler 
df_norm['Age'] = scaler.fit_transform(df_norm[['Age']]) # melakukan normalisasi pada kolom Age

# %% [markdown]
# ### Standarisasi pada dataset
# `codingan:`

# %%
df_std = df.copy() # membuat salinan dataset 
scaler = StandardScaler() # membuat objek scaler 
df_std = scaler.fit_transform(df_std[['Value', 'Wage']])# melakukan standarisasi

# %% [markdown]
# ### Data cleaning pada nilai null dan mengganti nilai null sesuai keinginan
# `codingan:`

# %%
df_clean = df.copy() # membuat salinan dataset 
df_clean.isnull().sum() # mengecek jumlah nilai null pada setiap kolom
# Out:
# Name                   0
# Age                    0
# Nationality            0
# Overall                0
# Potential              0
#                       ..
# Height                 0
# Weight                 0
# Right Foot             0
# Offensive Work Rate    0
# Defensive Work Rate    0
# Length: 82, dtype: int64

# %% [markdown]
# ### Dikarenakan tidak ada nilai null maka kita menambakan nilai null secara acak
# `codingan:`

# %%
np.random.seed(42) # menetapkan seed untuk reproduksi hasil 
df_clean.iloc[np.random.randint(0, len(df_clean), 10), np.random.randint(0, len(df_clean.columns), 10)] = np.nan # mengisi 10 nilai acak dengan null 
df_clean.isnull().sum() # mengecek kembali jumlah nilai null pada setiap kolom
# Out:
# Name                    0
# Age                    10
# Nationality            10
# Overall                 0
# Potential               0
#                        ..
# Height                  0
# Weight                  0
# Right Foot              0
# Offensive Work Rate     0
# Defensive Work Rate     0
# Length: 82, dtype: int64

# %% [markdown]
# ### Mengganti nilai null sesuai ketentuan
# `codingan:`

# %%
df_clean['Age'].fillna(df_clean['Age'].median(), inplace=True) # mengganti nilai null pada kolom Age dengan median 
df_clean['Nationality'].fillna(df_clean['Nationality'].mode()[0], inplace=True) # mengganti nilai null pada kolom Nationality dengan modus

# %% [markdown]
# ### Data cleaning pada nilai duplikat
# `codingan:`

# %%
df_dup = df.copy() # membuat salinan dataset 
df_dup.duplicated().sum() # mengecek jumlah baris yang duplikat
# Out:
# 0

# %% [markdown]
# ### Dikarenakan tidak ada nilai duplikat maka kita menambahkan nilai duplikat sendiri
# `codingan:`

# %%
df_dup.iloc[5,:] = df.iloc[10,:] # membuat data duplikat
df_dup.duplicated().sum() # mengecek jumlah baris yang duplikat
# Out:
# 1

# %% [markdown]
# ### Menghapus nilai duplikat
# `codingan:`

# %%
df_dup.drop_duplicates(inplace=True) # menghapus baris yang duplikat
df_dup.duplicated().sum() # mengecek jumlah baris yang duplikat
# Out:
# 0

# %% [markdown]
# ### Mengganti tipe salah satu tipe angka
# `codingan:`

# %%
df_type = df.copy() # membuat salinan dataset 
df_type.info() # menampilkan informasi tipe data setiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17219 entries, 0 to 17218
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17219 non-null  object
#  1   Age                       17219 non-null  int64
#  2   Nationality               17219 non-null  object
#  3   Overall                   17219 non-null  int64
#  4   Potential                 17219 non-null  int64
#  5   Club                      17219 non-null  object
#  6   Value                     17219 non-null  float64
#  7   Wage                      17219 non-null  float64
#  8   Special                   17219 non-null  int64
#  9   International Reputation  17219 non-null  float64
#  10  Weak Foot                 17219 non-null  float64
#  11  Skill Moves               17219 non-null  float64
#  12  Body Type                 17219 non-null  object
# ...

# %% [markdown]
# ### Mengganti tipe data pada atribut Age menjadi float
# `codingan:`

# %%
df_type['Age'] = df_type['Age'].astype(float) # mengganti tipe data kolom Age 
df_type.info() # menampilkan kembali informasi tipe data setiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17219 entries, 0 to 17218
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17219 non-null  object
#  1   Age                       17219 non-null  float64
#  2   Nationality               17219 non-null  object
#  3   Overall                   17219 non-null  int64
#  4   Potential                 17219 non-null  int64
#  5   Club                      17219 non-null  object
#  6   Value                     17219 non-null  float64
#  7   Wage                      17219 non-null  float64
#  8   Special                   17219 non-null  int64
#  9   International Reputation  17219 non-null  float64
#  10  Weak Foot                 17219 non-null  float64
#  11  Skill Moves               17219 non-null  float64
#  12  Body Type                 17219 non-null  object
# ...

# %% [markdown]
# ### Onehot Encoding
# `codingan:`

# %%
df_ohe = df.copy() # membuat salinan dataset 
ohe = OneHotEncoder(sparse=False) # membuat objek encoder 
df_ohe = pd.get_dummies(df_ohe, columns=['Nationality', 'Club']) # melakukan one hot encoding pada kolom Nationality dan Club 
df_ohe.head() # menampilkan lima baris pertama dari dataset yang sudah di-encode
# Out:
#                 Name  Age  Overall  Potential        Value      Wage  Special  \
# 0           L. Messi   31       94         94  110500000.0  565000.0     2202
# 1  Cristiano Ronaldo   33       94         94   77000000.0  405000.0     2228
# 2          Neymar Jr   26       92         93  118500000.0  290000.0     2143
# 3             De Gea   27       91         93   72000000.0  260000.0     1471
# 4       K. De Bruyne   27       91         92  102000000.0  355000.0     2281
#
#    International Reputation  Weak Foot  Skill Moves  ...  \
# 0                       5.0        4.0          4.0  ...
# 1                       5.0        4.0          5.0  ...
# 2                       5.0        5.0          5.0  ...
# 3                       4.0        3.0          1.0  ...
# 4                       4.0        5.0          4.0  ...
#
#   Club_Wolverhampton Wanderers Club_Wycombe Wanderers  Club_Yeni Malatyaspor  \
# ...
